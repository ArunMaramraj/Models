# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
temp = [1,2,3,4,5,6,7]
max = [50,48,51,54,56,57,44]
min = [55,53,49,44,60,61,39]
plt.xlabel("Days")
plt.ylabel("Temps")
plt.title("WEather")
plt.plot(temp,max,'r+--', label = "max")
plt.plot(temp,min, label= "MIN")

plt.legend(loc= "best")
