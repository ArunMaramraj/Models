# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# %%
x = [1,2,3,4,5,6,7]
y = [-1,0,-1,0,-1,0,-1]

# %%
plt.plot(x,y,color = 'red', linewidth = '9')
plt.xlabel('days')
plt.ylabel('chart')
plt.title('weather')
# Out:
# Text(0.5, 1.0, 'weather')
